# %% [markdown]
# # [Computational Social Science] Project 4: Unsupervised Learning
#
# **Enter your Name:** Paige Park
#
# *Semester:* Fall 2023

# %% [markdown]
# ## Data Description and Preprocessing
#
# For this project, you will explore data from the [National Health and Nutrition Examination Survey](https://www.kaggle.com/cdc/national-health-and-nutrition-examination-survey?select=questionnaire.csv). NHANES is a unique study that combines survey methodology with in-person medical examinations to create a dataset with demographic information, health indicators, and health outcomes.

# %% [markdown]
# We start by importing the data and doing some preliminary preprocessing for you. We import some libraries that will be helpful as well. 'SEQN' is the ID number for each respondent, and 'HSD010' will be our target outcome. [HSD010](https://wwwn.cdc.gov/Nchs/Nhanes/2013-2014/HSQ_H.htm#HSD010) asks for the respondent's self reported health condition, which can range from "excellent" to "poor."

# %%
# Import libraries
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.model_selection import train_test_split
sns.set_style("darkgrid")
from sklearn.model_selection import train_test_split

# %%
# Load nhanes data
nhanes = pd.read_csv('nhanes.csv')
# Get the ID numbers for each observation (seqn)
seqn = nhanes['SEQN']
# Get the target, "self-reported health condition," HSD010
hsd010 = nhanes['HSD010']
# Drop SEQN from the dataframe and then apply the standard scaler
nhanes = nhanes.drop(['SEQN', 'HSD010'], axis = 1)
nhanes_scaled = pd.DataFrame(StandardScaler().fit_transform(nhanes),
                             columns = nhanes.columns)
# Add the ID and target back in
nhanes_scaled['SEQN'] = seqn
nhanes_scaled['HSD010'] = hsd010
nhanes_scaled = nhanes_scaled.set_index('SEQN')
nhanes_scaled.head()
# Out:
#        DR1DRSTZ  DR1EXMER  DRABF    DRDINT   DR1DBIH    DR1DAY   DR1LANG  \
# SEQN
# 73568       0.0  2.034312    0.0  0.324834 -0.393906  1.085853 -0.194202
# 73576       0.0  0.261930    0.0 -3.078499  0.568251  0.634362 -0.194202
# 73579       0.0  0.728346    0.0  0.324834  1.530407 -1.623092 -0.194202
# 73581       0.0 -0.857470    0.0  0.324834  0.480782  1.085853 -0.194202
# 73584       0.0  0.495138    0.0  0.324834  0.305844 -1.623092 -0.194202
#
#        DR1MNRSP  DR1HELPD   DBQ095Z  ...    OHQ770    OHQ845   PAAQUEX  \
# SEQN                                 ...
# 73568 -0.057306  0.128246 -0.189513  ...  0.383802 -0.646584 -0.484200
# 73576 -0.057306  0.128246  0.080373  ...  0.383802 -1.539259 -0.484200
# 73579 -0.057306  0.128246 -0.189513  ...  0.383802 -1.539259  2.065262
# 73581 -0.057306  0.128246  0.080373  ...  0.383802 -0.646584 -0.484200
# 73584 -0.057306  0.128246  0.080373  ... -2.605509  0.246091  2.065262
#
#          SMQ860  SMQ870    SMQ872    SMQ874    SMQ878  SMAQUEX.x  HSD010
# SEQN
# 73568  1.125008     0.0 -2.081666  1.087115  1.463404   0.612440       1
# 73576  1.125008     0.0 -2.081666  1.087115 -0.683338  -1.632812       1
# 73579 -0.888883     0.0  0.480384 -0.919866 -0.683338  -1.632812       2
# 73581  1.125008     0.0  0.480384 -0.919866 -0.683338   0.612440       2
# 73584  1.125008     0.0  0.480384 -0.919866  1.463404  -1.632812       3
#
# [5 rows x 242 columns]

# %% [markdown]
# ## Plots

# %% [markdown]
# Let's take a look at the data. Below we visualize boxplots of family income to federal poverty line ratio ('INDFMPIR') and self-reported health condition. Notice how there are some clear patterns (the lower the ratio, the lower reported health condition), but it's not a perfect separation. We have 240+ features in our dataset, and we likely have several features in our dataset that highly correlate with our family income-poverty line ratio measure - PCA will help us simplify these.

# %%
# Create a binary version of hsd010 where 1-3 are "good" and 4-5 are "poor"
nhanes_scaled['HSD010_binary'] = hsd010_binary = nhanes_scaled['HSD010'].replace(
    [1, 2, 3, 4, 5], ['good', 'good', 'good', 'poor', 'poor']) 
# Recode the original hsd010 with the string labels
nhanes_scaled['HSD010'] = nhanes_scaled['HSD010'].replace(
    [1, 2, 3, 4, 5], ['excellent', 'very good', 'good', 'fair', 'poor'])
# Boxplot of hsd010
ax = sns.boxplot(x = 'HSD010', y = 'INDFMPIR', data = nhanes_scaled)
ax.set(xlabel = "Self Reported Health Condition",
      ylabel = "Family Income to Poverty Line Ratio")
ax.set_title("Boxplot of Family Income to Poverty Line Ratio by Self-Reported Health Status")
plt.show()

# %%
# Boxplot of hsd010_binary
ax = sns.boxplot(x = 'HSD010_binary', y = 'INDFMPIR', data = nhanes_scaled)
ax.set(xlabel = "Self Reported Health Condition",
      ylabel = "Family Income to Poverty Line Ratio")
ax.set_title("Boxplot of Family Income to Poverty Line Ratio by Binary Self-Reported Health Status")
plt.show()

# %% [markdown]
# Family income also is not necessarily well correlated with measured health outcomes. See below where we look at the relationship between Body Mass Index (BMI) and the family income-poverty line ratio, and shade points by self-reported health condition. It's hard to find a clear pattern - this is where clustering may come in handy.

# %%
ax = sns.scatterplot(x = "INDFMPIR", y = "BMXBMI", hue = "HSD010", palette = "tab10", data = nhanes_scaled)
ax.set(xlabel = "Income to Poverty Line Ratio",
      ylabel = "Body Mass Index")
ax.set_title("BMI v. Income-Poverty Ratio")
plt.show()

# %% [markdown]
# Before we move to working on unsupervised methods, we'll drop our target variables again:

# %%
nhanes_scaled = nhanes_scaled.drop(['HSD010', 'HSD010_binary'], axis = 1)

# %% [markdown]
# ## Principal Component Analysis

# %% [markdown]
# Conduct a Principal Component Analysis (PCA) of the nhanes data. The data has already been prepared for you, so you can work directly on nhanes_scaled. Be sure to do the following:
#
# - Choose the number of components and provide 1-2 sentences about your choice of the number of components.
# - Plot a barplot of the variation explained by each component. *Hint*: look at the attributes associated with your model.
# - Choose how many components you will use to fit a supervised learning model and provide 1-2 sentences to explain that choice.
# - Plot a 2D scatterplot of the first two components and provide 1-2 sentences analyzing the plot.

# %% [markdown]
# ### Train PCA and Discuss Number of Components

# %% [markdown]
# To start, I'll choose a relatively high number of components (150) so that I can examine the distribution of variance explained by each component and narrow down the number of features based on the results. I want to include a smaller number of features that explain the greatest amount of variance in the final model.

# %%
## PCA (fitting to data, transforming the data, creating dataframe)
pca = PCA(n_components=150, random_state=27)
pca.fit(nhanes_scaled)
nhanes_pca = pca.transform(nhanes_scaled)
#nhanes_pca_df = pd.DataFrame(data=nhanes_pca, columns=['PC1', 'PC2'])

# %% [markdown]
# ### Barplot of Components

# %% [markdown]
# The barplot shows that component 1 explains around 10% of the variation in the data, component 2 explains about 8%, and subsequent components decrease from there in a fairly regular way. Because the first few components don't explain a majority of the variation, we might want to keep more of the components than we otherwise would. In this case, it takes 150 components to capture around 96% of the variation.

# %%
## plot explained variance ratio
percent_variance = pca.explained_variance_ratio_ * 100
plt.figure(figsize=(10, 6))
plt.bar(range(1, len(percent_variance) + 1), percent_variance)
plt.xlabel('Principal Component')
plt.ylabel('Percentage of Variance Explained')
plt.title('PCA Explained Variance Ratio')
plt.xticks(range(1, len(percent_variance) + 1))
plt.show()

# %%
percent_variance.sum()
# Out:
# 95.81712248072947

# %% [markdown]
# ### How many components will you use to fit a supervised learning model?

# %% [markdown]
# Deciding how many components to use in a supervised model involves a trade-off between the amount of variance the components are able to capture and interpretabiltiy/simplicity. It seems like it would be good to reduce the number of components I'm using since 150 is still a very large number of features. I will take a hit on how much variance the components capture in exchange for additional dimensionality reduction. Let's see how much variance is captured by half as many features (75).

# %%
## PCA (fitting to data, transforming the data)
pca = PCA(n_components=75, random_state=27)
pca.fit(nhanes_scaled)
nhanes_pca = pca.transform(nhanes_scaled)

# %%
## plot explained variance ratio
percent_variance = pca.explained_variance_ratio_ * 100
plt.figure(figsize=(10, 6))
plt.bar(range(1, len(percent_variance) + 1), percent_variance)
plt.xlabel('Principal Component')
plt.ylabel('Percentage of Variance Explained')
plt.title('PCA Explained Variance Ratio')
plt.xticks(range(1, len(percent_variance) + 1))
plt.show()

# %% [markdown]
# 75 components capture about 75% of the variation in the data and are less unwieldy than using the original set of 150 features. I will use 75 components for the supervised model, but if this were a project I had more time and energy for, I might try out different numbers of components in the neural networks to see which number gives the best results.

# %%
percent_variance.sum()
# Out:
# 75.66075109965544

# %% [markdown]
# ### 2D Scatterplot of the first two components

# %% [markdown]
# The scatterplot below shows that there are some observations that appear to be clear outliers, especially with respect to the first component. Otherwise, the plot indicates that there might be two clusters of data - one larger cluster in the bottom left of the plot and the other in the top left.

# %%
plot = sns.scatterplot(x = nhanes_pca[:, 0], y = nhanes_pca[:, 1], data = nhanes_scaled)
plot.set(xlabel = "First Principal Component",
      ylabel = "Second Principal Component")
plot.set_title("2D Scatterplot of the First Two PCA Components")
plt.show()

# %% [markdown]
# ## K-Means

# %% [markdown]
# - Choose a clustering algorithm and explain it in 1-2 sentences.
# - Cluster the nhanes data. Detail any choice you need to make with regards to number of clusters, and how you arrived at that choice. For instance, you might use the [elbow method](https://en.wikipedia.org/wiki/Elbow_method_(clustering)) if you choose k-means.
# - Plot your clusters on top of BMI v. Income Poverty Ratio Plot. Describe what you see in 1-2 sentences.
# - Retrain the clustering algorithm, but this time use your PCA results instead of the original dataframe. Plot the clusters on top of the 2D PCA scatterplot from the previous step. Describe your results in 1-2 sentences.

# %% [markdown]
# ### Choose a Clustering Algorithm

# %% [markdown]
# I'm choosing the K-means algorithm. This algorithm iteratively sorts data into a pre-defined number of clusters, k, based on the Euclidean distance between data points and cluster centroids (at least in this case, though other distance measures can be used).

# %% [markdown]
# ### Cluster nhanes

# %% [markdown]
# The elbow method plot shows that at around 4 clusters, the inertia starts decreasing linearly indicating that k=4 is the "elbow" of the plot and we should select 4 for k in our algorithm.

# %%
# elbow method - plotting inertia as a function of the number of clusters 
inertias = []
for k in range(1,11):
    kmeans = KMeans(n_clusters=k, random_state=0, n_init=10)
    kmeans.fit(nhanes_scaled)
    inertias.append(kmeans.inertia_)

plt.plot(range(1, 11), inertias, 'bx-')
plt.xticks(range(1, 11))
plt.xlabel('Number of Clusters')
plt.ylabel('Inertias')
plt.title('Elbow Method For Optimal k')
plt.show()

# %%
# carrying out the k-means algorithm 
kmeans = KMeans(n_clusters=4, random_state=4, n_init=10)
kmeans.fit(nhanes_scaled)

# get the cluster assignments for each data point
cluster_kmeans = kmeans.predict(nhanes_scaled)

# %% [markdown]
# ### Plot your clusters on top of the BMI v. Income Poverty Ratio Plot

# %%
ax = sns.scatterplot(x = "INDFMPIR", y = "BMXBMI", hue = cluster_kmeans, palette = "tab10", data = nhanes_scaled)
ax.set(xlabel = "Income to Poverty Line Ratio",
      ylabel = "Body Mass Index")
ax.set_title("BMI v. Income-Poverty Ratio by Clusters")
plt.show()

# %% [markdown]
# The green cluster is concentrated on the higher end of the income to poverty line ratio than the red or blue clusters which are both highly concentrated among the lower ratios. The orange points seem to be randomly distributed on this plot and don't demonstrate an obvious pattern. None of the clusters seem to be strongly defined by BMI.

# %% [markdown]
# ### Retrain the clustering algorithm on PCA components and plot clusters on your 2D scatter

# %%
# elbow method - plotting inertia as a function of the number of clusters 
inertias = []
for k in range(1,11):
    kmeans = KMeans(n_clusters=k, random_state=0, n_init=10)
    kmeans.fit(nhanes_pca)
    inertias.append(kmeans.inertia_)

plt.plot(range(1, 11), inertias, 'bx-')
plt.xticks(range(1, 11))
plt.xlabel('Number of Clusters')
plt.ylabel('Inertias')
plt.title('Elbow Method For Optimal k')
plt.show()

# %%
# carrying out the k-means algorithm 
kmeans = KMeans(n_clusters=4, random_state=4, n_init=10)
kmeans.fit(nhanes_pca)

# get the cluster assignments for each data point
cluster_kmeans = kmeans.predict(nhanes_pca)

# %%
plot = sns.scatterplot(x=nhanes_pca[:, 0], y=nhanes_pca[:, 1], hue=cluster_kmeans, palette = "tab10", data=nhanes_scaled)
plot.set(xlabel = "First Principal Component",
      ylabel = "Second Principal Component")
plot.set_title("2D Scatterplot of the First Two PCA Components")
plt.show()

# %% [markdown]
# The clusters trained on the PCA components are much more clearly defined than those trained on the raw data. We see 4 distinctly seperated groups in the plot below, though the separation between the green and orange points seems arbitrary and not clearly defined. The blue and red clusters on the other hand are clearly seperated from each other and the other two clusters.

# %% [markdown]
# ## Neural Network

# %% [markdown]
# Now we are ready to predict! Do the following:
#
# - Choose either HSD010 or HSD010\_binary as your target outcome.
# - Train a neural network using the original features. Much of the code to train a basic neural net has been set up for you, but you will need to fill in a couple of missing pieces.
# - Train a neural network using only your PCA components as features.
# - Train a neural network using your PCA components and the predicted class membership from your clustering algorithm as features.
# - Compare and contrast how well each algorithm did. Which featurization technique would you pick and why?

# %% [markdown]
# Below we provide a template for training a neural network. Use this template for training on the original features, on the PCA components, and the PCA components + the predicted classes from your clusters.

# %% [markdown]
# ### Neural Network on Original Features

# %%
# partition data
# -----------
y = hsd010_binary # either hsd010 or hsd010_binary, may need to convert to numeric if it isn't already 
X = nhanes_scaled # drop out any columns that aren't features

X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size=.25, 
                                                    random_state=10)

X_train, X_val, y_train, y_val = train_test_split(X_train,
                                                  y_train,
                                                  test_size=.2,
                                                  random_state=10)

# %%
# load libraries
# -----------
import keras
from tensorflow.keras import initializers

# convert y_train and y_test to integers 
y_train = y_train.map({'good': 1, 'poor': 0})
y_test = y_test.map({'good': 1, 'poor': 0})
y_val = y_val.map({'good': 1, 'poor': 0})

# don't need to use one hot encoding since the binary version of y is already in a binary format    
    # num_classes = 2
    # convert class vectors to binary class matrices
    # y_train = keras.utils.to_categorical(y_train, num_classes=num_classes)
    # y_test = keras.utils.to_categorical(y_test, num_classes=num_classes)
    # num_classes = y_test.shape[1]

# %%
# create neural network model
# -----------
model = Sequential()
model.add(keras.Input(shape=(241,)))
model.add(Dense(64, kernel_initializer=initializers.RandomNormal(seed=27), activation= 'relu'))
model.add(Dense(1, kernel_initializer=initializers.RandomNormal(seed=27), activation= 'sigmoid'))
model.summary()

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=128, verbose=2)
# Out:
# Model: "sequential_28"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_52 (Dense)            (None, 64)                15488
#
#  dense_53 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 15553 (60.75 KB)
# Trainable params: 15553 (60.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 10/10 - 0s - loss: 0.6558 - accuracy: 0.6446 - val_loss: 0.5918 - val_accuracy: 0.8032 - 241ms/epoch - 24ms/step
# Epoch 2/50
# 10/10 - 0s - loss: 0.5264 - accuracy: 0.8425 - val_loss: 0.5022 - val_accuracy: 0.8097 - 19ms/epoch - 2ms/step
# Epoch 3/50
# 10/10 - 0s - loss: 0.4329 - accuracy: 0.8619 - val_loss: 0.4465 - val_accuracy: 0.8258 - 20ms/epoch - 2ms/step
# Epoch 4/50
# 10/10 - 0s - loss: 0.3739 - accuracy: 0.8708 - val_loss: 0.4209 - val_accuracy: 0.8290 - 19ms/epoch - 2ms/step
# Epoch 5/50
# 10/10 - 0s - loss: 0.3412 - accuracy: 0.8869 - val_loss: 0.4133 - val_accuracy: 0.8323 - 20ms/epoch - 2ms/step
# Epoch 6/50
# 10/10 - 0s - loss: 0.3198 - accuracy: 0.8885 - val_loss: 0.4115 - val_accuracy: 0.8355 - 19ms/epoch - 2ms/step
# Epoch 7/50
# 10/10 - 0s - loss: 0.3026 - accuracy: 0.8910 - val_loss: 0.4090 - val_accuracy: 0.8387 - 19ms/epoch - 2ms/step
# Epoch 8/50
# 10/10 - 0s - loss: 0.2867 - accuracy: 0.8942 - val_loss: 0.4054 - val_accuracy: 0.8323 - 19ms/epoch - 2ms/step
# Epoch 9/50
# 10/10 - 0s - loss: 0.2715 - accuracy: 0.8974 - val_loss: 0.4032 - val_accuracy: 0.8355 - 19ms/epoch - 2ms/step
# Epoch 10/50
# 10/10 - 0s - loss: 0.2570 - accuracy: 0.9039 - val_loss: 0.4021 - val_accuracy: 0.8355 - 19ms/epoch - 2ms/step
# Epoch 11/50
# 10/10 - 0s - loss: 0.2438 - accuracy: 0.9071 - val_loss: 0.4030 - val_accuracy: 0.8355 - 19ms/epoch - 2ms/step
# Epoch 12/50
# 10/10 - 0s - loss: 0.2298 - accuracy: 0.9111 - val_loss: 0.4041 - val_accuracy: 0.8355 - 19ms/epoch - 2ms/step
# Epoch 13/50
# 10/10 - 0s - loss: 0.2172 - accuracy: 0.9192 - val_loss: 0.4048 - val_accuracy: 0.8387 - 19ms/epoch - 2ms/step
# Epoch 14/50
# 10/10 - 0s - loss: 0.2047 - accuracy: 0.9257 - val_loss: 0.4028 - val_accuracy: 0.8355 - 19ms/epoch - 2ms/step
# Epoch 15/50
# 10/10 - 0s - loss: 0.1938 - accuracy: 0.9265 - val_loss: 0.4077 - val_accuracy: 0.8323 - 18ms/epoch - 2ms/step
# Epoch 16/50
# 10/10 - 0s - loss: 0.1823 - accuracy: 0.9313 - val_loss: 0.4141 - val_accuracy: 0.8323 - 19ms/epoch - 2ms/step
# Epoch 17/50
# 10/10 - 0s - loss: 0.1717 - accuracy: 0.9370 - val_loss: 0.4152 - val_accuracy: 0.8258 - 19ms/epoch - 2ms/step
# Epoch 18/50
# 10/10 - 0s - loss: 0.1620 - accuracy: 0.9394 - val_loss: 0.4190 - val_accuracy: 0.8226 - 18ms/epoch - 2ms/step
# Epoch 19/50
# 10/10 - 0s - loss: 0.1518 - accuracy: 0.9394 - val_loss: 0.4257 - val_accuracy: 0.8226 - 19ms/epoch - 2ms/step
# Epoch 20/50
# 10/10 - 0s - loss: 0.1427 - accuracy: 0.9483 - val_loss: 0.4308 - val_accuracy: 0.8258 - 19ms/epoch - 2ms/step
# Epoch 21/50
# 10/10 - 0s - loss: 0.1340 - accuracy: 0.9572 - val_loss: 0.4356 - val_accuracy: 0.8226 - 19ms/epoch - 2ms/step
# Epoch 22/50
# 10/10 - 0s - loss: 0.1260 - accuracy: 0.9588 - val_loss: 0.4400 - val_accuracy: 0.8226 - 19ms/epoch - 2ms/step
# Epoch 23/50
# 10/10 - 0s - loss: 0.1184 - accuracy: 0.9645 - val_loss: 0.4438 - val_accuracy: 0.8226 - 19ms/epoch - 2ms/step
# Epoch 24/50
# 10/10 - 0s - loss: 0.1107 - accuracy: 0.9669 - val_loss: 0.4499 - val_accuracy: 0.8226 - 19ms/epoch - 2ms/step
# Epoch 25/50
# 10/10 - 0s - loss: 0.1041 - accuracy: 0.9693 - val_loss: 0.4556 - val_accuracy: 0.8290 - 19ms/epoch - 2ms/step
# Epoch 26/50
# 10/10 - 0s - loss: 0.0975 - accuracy: 0.9717 - val_loss: 0.4607 - val_accuracy: 0.8290 - 19ms/epoch - 2ms/step
# Epoch 27/50
# 10/10 - 0s - loss: 0.0913 - accuracy: 0.9742 - val_loss: 0.4676 - val_accuracy: 0.8290 - 19ms/epoch - 2ms/step
# Epoch 28/50
# 10/10 - 0s - loss: 0.0854 - accuracy: 0.9782 - val_loss: 0.4734 - val_accuracy: 0.8323 - 18ms/epoch - 2ms/step
# Epoch 29/50
# 10/10 - 0s - loss: 0.0803 - accuracy: 0.9798 - val_loss: 0.4795 - val_accuracy: 0.8323 - 19ms/epoch - 2ms/step
# Epoch 30/50
# 10/10 - 0s - loss: 0.0754 - accuracy: 0.9806 - val_loss: 0.4809 - val_accuracy: 0.8323 - 19ms/epoch - 2ms/step
# Epoch 31/50
# 10/10 - 0s - loss: 0.0707 - accuracy: 0.9838 - val_loss: 0.4898 - val_accuracy: 0.8323 - 19ms/epoch - 2ms/step
# Epoch 32/50
# 10/10 - 0s - loss: 0.0658 - accuracy: 0.9847 - val_loss: 0.4932 - val_accuracy: 0.8355 - 18ms/epoch - 2ms/step
# Epoch 33/50
# 10/10 - 0s - loss: 0.0616 - accuracy: 0.9879 - val_loss: 0.4979 - val_accuracy: 0.8387 - 18ms/epoch - 2ms/step
# Epoch 34/50
# 10/10 - 0s - loss: 0.0575 - accuracy: 0.9911 - val_loss: 0.5061 - val_accuracy: 0.8419 - 19ms/epoch - 2ms/step
# Epoch 35/50
# 10/10 - 0s - loss: 0.0540 - accuracy: 0.9919 - val_loss: 0.5096 - val_accuracy: 0.8387 - 19ms/epoch - 2ms/step
# Epoch 36/50
# 10/10 - 0s - loss: 0.0508 - accuracy: 0.9927 - val_loss: 0.5156 - val_accuracy: 0.8323 - 19ms/epoch - 2ms/step
# Epoch 37/50
# 10/10 - 0s - loss: 0.0478 - accuracy: 0.9927 - val_loss: 0.5250 - val_accuracy: 0.8419 - 19ms/epoch - 2ms/step
# Epoch 38/50
# 10/10 - 0s - loss: 0.0443 - accuracy: 0.9943 - val_loss: 0.5247 - val_accuracy: 0.8387 - 18ms/epoch - 2ms/step
# Epoch 39/50
# 10/10 - 0s - loss: 0.0414 - accuracy: 0.9968 - val_loss: 0.5334 - val_accuracy: 0.8387 - 18ms/epoch - 2ms/step
# Epoch 40/50
# 10/10 - 0s - loss: 0.0388 - accuracy: 0.9968 - val_loss: 0.5402 - val_accuracy: 0.8387 - 19ms/epoch - 2ms/step
# Epoch 41/50
# 10/10 - 0s - loss: 0.0365 - accuracy: 0.9976 - val_loss: 0.5460 - val_accuracy: 0.8387 - 18ms/epoch - 2ms/step
# Epoch 42/50
# 10/10 - 0s - loss: 0.0343 - accuracy: 0.9992 - val_loss: 0.5512 - val_accuracy: 0.8355 - 18ms/epoch - 2ms/step
# Epoch 43/50
# 10/10 - 0s - loss: 0.0321 - accuracy: 1.0000 - val_loss: 0.5560 - val_accuracy: 0.8355 - 19ms/epoch - 2ms/step
# Epoch 44/50
# 10/10 - 0s - loss: 0.0302 - accuracy: 1.0000 - val_loss: 0.5606 - val_accuracy: 0.8355 - 18ms/epoch - 2ms/step
# Epoch 45/50
# 10/10 - 0s - loss: 0.0286 - accuracy: 1.0000 - val_loss: 0.5682 - val_accuracy: 0.8387 - 43ms/epoch - 4ms/step
# Epoch 46/50
# 10/10 - 0s - loss: 0.0269 - accuracy: 1.0000 - val_loss: 0.5751 - val_accuracy: 0.8355 - 19ms/epoch - 2ms/step
# Epoch 47/50
# 10/10 - 0s - loss: 0.0252 - accuracy: 1.0000 - val_loss: 0.5815 - val_accuracy: 0.8355 - 19ms/epoch - 2ms/step
# Epoch 48/50
# 10/10 - 0s - loss: 0.0238 - accuracy: 1.0000 - val_loss: 0.5839 - val_accuracy: 0.8355 - 19ms/epoch - 2ms/step
# Epoch 49/50
# 10/10 - 0s - loss: 0.0226 - accuracy: 1.0000 - val_loss: 0.5889 - val_accuracy: 0.8387 - 29ms/epoch - 3ms/step
# Epoch 50/50
# 10/10 - 0s - loss: 0.0213 - accuracy: 1.0000 - val_loss: 0.5979 - val_accuracy: 0.8387 - 19ms/epoch - 2ms/step

# %%
max_val_accuracy = max(history.history['val_accuracy'])
print(f"Maximum Validation Accuracy: {max_val_accuracy * 100:.2f}%")
# Out:
# Maximum Validation Accuracy: 84.19%

# %% [markdown]
# ### Neural Network on Principal Components

# %%
# partition data
# -----------
y = hsd010_binary # either hsd010 or hsd010_binary, may need to convert to numeric if it isn't already 
X = nhanes_pca # drop out any columns that aren't features

X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size=.25, 
                                                    random_state=10)

X_train, X_val, y_train, y_val = train_test_split(X_train,
                                                  y_train,
                                                  test_size=.2,
                                                  random_state=10)

# convert y_train and y_test to integers 
y_train = y_train.map({'good': 1, 'poor': 0})
y_test = y_test.map({'good': 1, 'poor': 0})
y_val = y_val.map({'good': 1, 'poor': 0})

# %%
# create neural network model
# -----------
model = Sequential()
model.add(keras.Input(shape=(75,)))
model.add(Dense(64, kernel_initializer=initializers.RandomNormal(seed=27), activation= 'relu'))
model.add(Dense(1, kernel_initializer=initializers.RandomNormal(seed=27), activation= 'sigmoid'))
model.summary()

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=128, verbose=2)
# Out:
# Model: "sequential_29"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_54 (Dense)            (None, 64)                4864
#
#  dense_55 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 4929 (19.25 KB)
# Trainable params: 4929 (19.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 10/10 - 0s - loss: 0.6712 - accuracy: 0.5598 - val_loss: 0.6376 - val_accuracy: 0.6516 - 199ms/epoch - 20ms/step
# Epoch 2/50
# 10/10 - 0s - loss: 0.5903 - accuracy: 0.7504 - val_loss: 0.5768 - val_accuracy: 0.8097 - 18ms/epoch - 2ms/step
# Epoch 3/50
# 10/10 - 0s - loss: 0.5249 - accuracy: 0.8562 - val_loss: 0.5285 - val_accuracy: 0.8226 - 17ms/epoch - 2ms/step
# Epoch 4/50
# 10/10 - 0s - loss: 0.4720 - accuracy: 0.8691 - val_loss: 0.4889 - val_accuracy: 0.8290 - 17ms/epoch - 2ms/step
# Epoch 5/50
# 10/10 - 0s - loss: 0.4276 - accuracy: 0.8716 - val_loss: 0.4569 - val_accuracy: 0.8387 - 18ms/epoch - 2ms/step
# Epoch 6/50
# 10/10 - 0s - loss: 0.3898 - accuracy: 0.8732 - val_loss: 0.4317 - val_accuracy: 0.8355 - 18ms/epoch - 2ms/step
# Epoch 7/50
# 10/10 - 0s - loss: 0.3584 - accuracy: 0.8788 - val_loss: 0.4121 - val_accuracy: 0.8387 - 18ms/epoch - 2ms/step
# Epoch 8/50
# 10/10 - 0s - loss: 0.3323 - accuracy: 0.8821 - val_loss: 0.3990 - val_accuracy: 0.8452 - 18ms/epoch - 2ms/step
# Epoch 9/50
# 10/10 - 0s - loss: 0.3120 - accuracy: 0.8861 - val_loss: 0.3892 - val_accuracy: 0.8484 - 17ms/epoch - 2ms/step
# Epoch 10/50
# 10/10 - 0s - loss: 0.2947 - accuracy: 0.8893 - val_loss: 0.3837 - val_accuracy: 0.8548 - 17ms/epoch - 2ms/step
# Epoch 11/50
# 10/10 - 0s - loss: 0.2811 - accuracy: 0.8926 - val_loss: 0.3810 - val_accuracy: 0.8581 - 17ms/epoch - 2ms/step
# Epoch 12/50
# 10/10 - 0s - loss: 0.2691 - accuracy: 0.8966 - val_loss: 0.3804 - val_accuracy: 0.8581 - 17ms/epoch - 2ms/step
# Epoch 13/50
# 10/10 - 0s - loss: 0.2589 - accuracy: 0.8982 - val_loss: 0.3812 - val_accuracy: 0.8613 - 17ms/epoch - 2ms/step
# Epoch 14/50
# 10/10 - 0s - loss: 0.2501 - accuracy: 0.9031 - val_loss: 0.3810 - val_accuracy: 0.8613 - 17ms/epoch - 2ms/step
# Epoch 15/50
# 10/10 - 0s - loss: 0.2424 - accuracy: 0.9055 - val_loss: 0.3839 - val_accuracy: 0.8613 - 17ms/epoch - 2ms/step
# Epoch 16/50
# 10/10 - 0s - loss: 0.2351 - accuracy: 0.9087 - val_loss: 0.3879 - val_accuracy: 0.8613 - 41ms/epoch - 4ms/step
# Epoch 17/50
# 10/10 - 0s - loss: 0.2283 - accuracy: 0.9103 - val_loss: 0.3899 - val_accuracy: 0.8613 - 18ms/epoch - 2ms/step
# Epoch 18/50
# 10/10 - 0s - loss: 0.2224 - accuracy: 0.9120 - val_loss: 0.3919 - val_accuracy: 0.8581 - 17ms/epoch - 2ms/step
# Epoch 19/50
# 10/10 - 0s - loss: 0.2164 - accuracy: 0.9120 - val_loss: 0.3967 - val_accuracy: 0.8548 - 17ms/epoch - 2ms/step
# Epoch 20/50
# 10/10 - 0s - loss: 0.2109 - accuracy: 0.9176 - val_loss: 0.4013 - val_accuracy: 0.8548 - 17ms/epoch - 2ms/step
# Epoch 21/50
# 10/10 - 0s - loss: 0.2055 - accuracy: 0.9192 - val_loss: 0.4048 - val_accuracy: 0.8548 - 17ms/epoch - 2ms/step
# Epoch 22/50
# 10/10 - 0s - loss: 0.2004 - accuracy: 0.9208 - val_loss: 0.4087 - val_accuracy: 0.8548 - 17ms/epoch - 2ms/step
# Epoch 23/50
# 10/10 - 0s - loss: 0.1956 - accuracy: 0.9233 - val_loss: 0.4129 - val_accuracy: 0.8516 - 17ms/epoch - 2ms/step
# Epoch 24/50
# 10/10 - 0s - loss: 0.1904 - accuracy: 0.9257 - val_loss: 0.4167 - val_accuracy: 0.8516 - 17ms/epoch - 2ms/step
# Epoch 25/50
# 10/10 - 0s - loss: 0.1856 - accuracy: 0.9289 - val_loss: 0.4212 - val_accuracy: 0.8484 - 17ms/epoch - 2ms/step
# Epoch 26/50
# 10/10 - 0s - loss: 0.1813 - accuracy: 0.9313 - val_loss: 0.4252 - val_accuracy: 0.8516 - 17ms/epoch - 2ms/step
# Epoch 27/50
# 10/10 - 0s - loss: 0.1766 - accuracy: 0.9338 - val_loss: 0.4294 - val_accuracy: 0.8516 - 17ms/epoch - 2ms/step
# Epoch 28/50
# 10/10 - 0s - loss: 0.1720 - accuracy: 0.9386 - val_loss: 0.4338 - val_accuracy: 0.8516 - 17ms/epoch - 2ms/step
# Epoch 29/50
# 10/10 - 0s - loss: 0.1679 - accuracy: 0.9386 - val_loss: 0.4393 - val_accuracy: 0.8516 - 17ms/epoch - 2ms/step
# Epoch 30/50
# 10/10 - 0s - loss: 0.1638 - accuracy: 0.9386 - val_loss: 0.4415 - val_accuracy: 0.8516 - 17ms/epoch - 2ms/step
# Epoch 31/50
# 10/10 - 0s - loss: 0.1593 - accuracy: 0.9435 - val_loss: 0.4484 - val_accuracy: 0.8516 - 17ms/epoch - 2ms/step
# Epoch 32/50
# 10/10 - 0s - loss: 0.1550 - accuracy: 0.9451 - val_loss: 0.4526 - val_accuracy: 0.8516 - 17ms/epoch - 2ms/step
# Epoch 33/50
# 10/10 - 0s - loss: 0.1507 - accuracy: 0.9491 - val_loss: 0.4571 - val_accuracy: 0.8484 - 17ms/epoch - 2ms/step
# Epoch 34/50
# 10/10 - 0s - loss: 0.1465 - accuracy: 0.9515 - val_loss: 0.4620 - val_accuracy: 0.8452 - 17ms/epoch - 2ms/step
# Epoch 35/50
# 10/10 - 0s - loss: 0.1425 - accuracy: 0.9515 - val_loss: 0.4651 - val_accuracy: 0.8516 - 17ms/epoch - 2ms/step
# Epoch 36/50
# 10/10 - 0s - loss: 0.1387 - accuracy: 0.9532 - val_loss: 0.4681 - val_accuracy: 0.8516 - 17ms/epoch - 2ms/step
# Epoch 37/50
# 10/10 - 0s - loss: 0.1345 - accuracy: 0.9540 - val_loss: 0.4752 - val_accuracy: 0.8516 - 17ms/epoch - 2ms/step
# Epoch 38/50
# 10/10 - 0s - loss: 0.1303 - accuracy: 0.9548 - val_loss: 0.4790 - val_accuracy: 0.8516 - 17ms/epoch - 2ms/step
# Epoch 39/50
# 10/10 - 0s - loss: 0.1267 - accuracy: 0.9572 - val_loss: 0.4840 - val_accuracy: 0.8548 - 17ms/epoch - 2ms/step
# Epoch 40/50
# 10/10 - 0s - loss: 0.1227 - accuracy: 0.9572 - val_loss: 0.4881 - val_accuracy: 0.8484 - 17ms/epoch - 2ms/step
# Epoch 41/50
# 10/10 - 0s - loss: 0.1191 - accuracy: 0.9572 - val_loss: 0.4933 - val_accuracy: 0.8484 - 17ms/epoch - 2ms/step
# Epoch 42/50
# 10/10 - 0s - loss: 0.1155 - accuracy: 0.9588 - val_loss: 0.4975 - val_accuracy: 0.8484 - 16ms/epoch - 2ms/step
# Epoch 43/50
# 10/10 - 0s - loss: 0.1117 - accuracy: 0.9604 - val_loss: 0.5022 - val_accuracy: 0.8452 - 17ms/epoch - 2ms/step
# Epoch 44/50
# 10/10 - 0s - loss: 0.1081 - accuracy: 0.9637 - val_loss: 0.5056 - val_accuracy: 0.8452 - 18ms/epoch - 2ms/step
# Epoch 45/50
# 10/10 - 0s - loss: 0.1048 - accuracy: 0.9645 - val_loss: 0.5104 - val_accuracy: 0.8419 - 17ms/epoch - 2ms/step
# Epoch 46/50
# 10/10 - 0s - loss: 0.1012 - accuracy: 0.9669 - val_loss: 0.5163 - val_accuracy: 0.8452 - 17ms/epoch - 2ms/step
# Epoch 47/50
# 10/10 - 0s - loss: 0.0979 - accuracy: 0.9701 - val_loss: 0.5223 - val_accuracy: 0.8419 - 17ms/epoch - 2ms/step
# Epoch 48/50
# 10/10 - 0s - loss: 0.0946 - accuracy: 0.9709 - val_loss: 0.5268 - val_accuracy: 0.8452 - 16ms/epoch - 2ms/step
# Epoch 49/50
# 10/10 - 0s - loss: 0.0916 - accuracy: 0.9709 - val_loss: 0.5306 - val_accuracy: 0.8387 - 17ms/epoch - 2ms/step
# Epoch 50/50
# 10/10 - 0s - loss: 0.0881 - accuracy: 0.9717 - val_loss: 0.5369 - val_accuracy: 0.8452 - 17ms/epoch - 2ms/step

# %%
max_val_accuracy = max(history.history['val_accuracy'])
print(f"Maximum Validation Accuracy: {max_val_accuracy * 100:.2f}%")
# Out:
# Maximum Validation Accuracy: 86.13%

# %% [markdown]
# ### Neural Network on Principal Components + Cluster Membership

# %%
nhanes_pca_and_cluster = np.column_stack((nhanes_pca, cluster_kmeans))
nhanes_pca_and_cluster.shape
# Out:
# (2064, 76)

# %%
# partition data
# -----------
y = hsd010_binary # either hsd010 or hsd010_binary, may need to convert to numeric if it isn't already 
X = nhanes_pca_and_cluster # drop out any columns that aren't features

X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size=.25, 
                                                    random_state=10)

X_train, X_val, y_train, y_val = train_test_split(X_train,
                                                  y_train,
                                                  test_size=.2,
                                                  random_state=10)

# convert y_train and y_test to integers 
y_train = y_train.map({'good': 1, 'poor': 0})
y_test = y_test.map({'good': 1, 'poor': 0})
y_val = y_val.map({'good': 1, 'poor': 0})

# %%
# create neural network model
# -----------
model = Sequential()
model.add(keras.Input(shape=(76,)))
model.add(Dense(64, kernel_initializer=initializers.RandomNormal(seed=27), activation= 'relu'))
model.add(Dense(1, kernel_initializer=initializers.RandomNormal(seed=27), activation= 'sigmoid'))
model.summary()

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=128, verbose=2)
# Out:
# Model: "sequential_30"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_56 (Dense)            (None, 64)                4928
#
#  dense_57 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 4993 (19.50 KB)
# Trainable params: 4993 (19.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 10/10 - 0s - loss: 0.6742 - accuracy: 0.5468 - val_loss: 0.6392 - val_accuracy: 0.6516 - 204ms/epoch - 20ms/step
# Epoch 2/50
# 10/10 - 0s - loss: 0.5913 - accuracy: 0.7520 - val_loss: 0.5770 - val_accuracy: 0.8032 - 18ms/epoch - 2ms/step
# Epoch 3/50
# 10/10 - 0s - loss: 0.5245 - accuracy: 0.8570 - val_loss: 0.5277 - val_accuracy: 0.8226 - 18ms/epoch - 2ms/step
# Epoch 4/50
# 10/10 - 0s - loss: 0.4705 - accuracy: 0.8667 - val_loss: 0.4875 - val_accuracy: 0.8323 - 17ms/epoch - 2ms/step
# Epoch 5/50
# 10/10 - 0s - loss: 0.4251 - accuracy: 0.8708 - val_loss: 0.4551 - val_accuracy: 0.8258 - 18ms/epoch - 2ms/step
# Epoch 6/50
# 10/10 - 0s - loss: 0.3866 - accuracy: 0.8732 - val_loss: 0.4302 - val_accuracy: 0.8323 - 17ms/epoch - 2ms/step
# Epoch 7/50
# 10/10 - 0s - loss: 0.3549 - accuracy: 0.8772 - val_loss: 0.4112 - val_accuracy: 0.8323 - 18ms/epoch - 2ms/step
# Epoch 8/50
# 10/10 - 0s - loss: 0.3288 - accuracy: 0.8772 - val_loss: 0.3988 - val_accuracy: 0.8323 - 18ms/epoch - 2ms/step
# Epoch 9/50
# 10/10 - 0s - loss: 0.3087 - accuracy: 0.8813 - val_loss: 0.3896 - val_accuracy: 0.8419 - 17ms/epoch - 2ms/step
# Epoch 10/50
# 10/10 - 0s - loss: 0.2918 - accuracy: 0.8877 - val_loss: 0.3848 - val_accuracy: 0.8484 - 17ms/epoch - 2ms/step
# Epoch 11/50
# 10/10 - 0s - loss: 0.2786 - accuracy: 0.8950 - val_loss: 0.3828 - val_accuracy: 0.8484 - 17ms/epoch - 2ms/step
# Epoch 12/50
# 10/10 - 0s - loss: 0.2671 - accuracy: 0.8974 - val_loss: 0.3826 - val_accuracy: 0.8613 - 17ms/epoch - 2ms/step
# Epoch 13/50
# 10/10 - 0s - loss: 0.2573 - accuracy: 0.9015 - val_loss: 0.3836 - val_accuracy: 0.8613 - 17ms/epoch - 2ms/step
# Epoch 14/50
# 10/10 - 0s - loss: 0.2487 - accuracy: 0.9047 - val_loss: 0.3836 - val_accuracy: 0.8645 - 17ms/epoch - 2ms/step
# Epoch 15/50
# 10/10 - 0s - loss: 0.2413 - accuracy: 0.9071 - val_loss: 0.3870 - val_accuracy: 0.8645 - 17ms/epoch - 2ms/step
# Epoch 16/50
# 10/10 - 0s - loss: 0.2341 - accuracy: 0.9095 - val_loss: 0.3918 - val_accuracy: 0.8613 - 17ms/epoch - 2ms/step
# Epoch 17/50
# 10/10 - 0s - loss: 0.2275 - accuracy: 0.9095 - val_loss: 0.3940 - val_accuracy: 0.8581 - 17ms/epoch - 2ms/step
# Epoch 18/50
# 10/10 - 0s - loss: 0.2217 - accuracy: 0.9120 - val_loss: 0.3961 - val_accuracy: 0.8516 - 17ms/epoch - 2ms/step
# Epoch 19/50
# 10/10 - 0s - loss: 0.2156 - accuracy: 0.9111 - val_loss: 0.4016 - val_accuracy: 0.8516 - 17ms/epoch - 2ms/step
# Epoch 20/50
# 10/10 - 0s - loss: 0.2103 - accuracy: 0.9152 - val_loss: 0.4062 - val_accuracy: 0.8484 - 17ms/epoch - 2ms/step
# Epoch 21/50
# 10/10 - 0s - loss: 0.2048 - accuracy: 0.9184 - val_loss: 0.4099 - val_accuracy: 0.8452 - 17ms/epoch - 2ms/step
# Epoch 22/50
# 10/10 - 0s - loss: 0.1999 - accuracy: 0.9225 - val_loss: 0.4137 - val_accuracy: 0.8452 - 17ms/epoch - 2ms/step
# Epoch 23/50
# 10/10 - 0s - loss: 0.1951 - accuracy: 0.9241 - val_loss: 0.4177 - val_accuracy: 0.8452 - 17ms/epoch - 2ms/step
# Epoch 24/50
# 10/10 - 0s - loss: 0.1898 - accuracy: 0.9265 - val_loss: 0.4216 - val_accuracy: 0.8452 - 17ms/epoch - 2ms/step
# Epoch 25/50
# 10/10 - 0s - loss: 0.1850 - accuracy: 0.9281 - val_loss: 0.4267 - val_accuracy: 0.8452 - 17ms/epoch - 2ms/step
# Epoch 26/50
# 10/10 - 0s - loss: 0.1808 - accuracy: 0.9313 - val_loss: 0.4308 - val_accuracy: 0.8484 - 17ms/epoch - 2ms/step
# Epoch 27/50
# 10/10 - 0s - loss: 0.1760 - accuracy: 0.9354 - val_loss: 0.4353 - val_accuracy: 0.8516 - 17ms/epoch - 2ms/step
# Epoch 28/50
# 10/10 - 0s - loss: 0.1713 - accuracy: 0.9378 - val_loss: 0.4398 - val_accuracy: 0.8516 - 17ms/epoch - 2ms/step
# Epoch 29/50
# 10/10 - 0s - loss: 0.1672 - accuracy: 0.9386 - val_loss: 0.4459 - val_accuracy: 0.8516 - 17ms/epoch - 2ms/step
# Epoch 30/50
# 10/10 - 0s - loss: 0.1631 - accuracy: 0.9394 - val_loss: 0.4477 - val_accuracy: 0.8516 - 17ms/epoch - 2ms/step
# Epoch 31/50
# 10/10 - 0s - loss: 0.1585 - accuracy: 0.9435 - val_loss: 0.4548 - val_accuracy: 0.8516 - 18ms/epoch - 2ms/step
# Epoch 32/50
# 10/10 - 0s - loss: 0.1540 - accuracy: 0.9451 - val_loss: 0.4593 - val_accuracy: 0.8484 - 17ms/epoch - 2ms/step
# Epoch 33/50
# 10/10 - 0s - loss: 0.1496 - accuracy: 0.9459 - val_loss: 0.4635 - val_accuracy: 0.8484 - 18ms/epoch - 2ms/step
# Epoch 34/50
# 10/10 - 0s - loss: 0.1454 - accuracy: 0.9499 - val_loss: 0.4690 - val_accuracy: 0.8484 - 17ms/epoch - 2ms/step
# Epoch 35/50
# 10/10 - 0s - loss: 0.1413 - accuracy: 0.9540 - val_loss: 0.4723 - val_accuracy: 0.8484 - 17ms/epoch - 2ms/step
# Epoch 36/50
# 10/10 - 0s - loss: 0.1373 - accuracy: 0.9556 - val_loss: 0.4755 - val_accuracy: 0.8484 - 17ms/epoch - 2ms/step
# Epoch 37/50
# 10/10 - 0s - loss: 0.1331 - accuracy: 0.9556 - val_loss: 0.4828 - val_accuracy: 0.8548 - 17ms/epoch - 2ms/step
# Epoch 38/50
# 10/10 - 0s - loss: 0.1288 - accuracy: 0.9564 - val_loss: 0.4866 - val_accuracy: 0.8548 - 17ms/epoch - 2ms/step
# Epoch 39/50
# 10/10 - 0s - loss: 0.1251 - accuracy: 0.9588 - val_loss: 0.4915 - val_accuracy: 0.8548 - 17ms/epoch - 2ms/step
# Epoch 40/50
# 10/10 - 0s - loss: 0.1208 - accuracy: 0.9596 - val_loss: 0.4962 - val_accuracy: 0.8548 - 17ms/epoch - 2ms/step
# Epoch 41/50
# 10/10 - 0s - loss: 0.1172 - accuracy: 0.9580 - val_loss: 0.5010 - val_accuracy: 0.8548 - 17ms/epoch - 2ms/step
# Epoch 42/50
# 10/10 - 0s - loss: 0.1134 - accuracy: 0.9596 - val_loss: 0.5060 - val_accuracy: 0.8548 - 17ms/epoch - 2ms/step
# Epoch 43/50
# 10/10 - 0s - loss: 0.1094 - accuracy: 0.9604 - val_loss: 0.5106 - val_accuracy: 0.8548 - 17ms/epoch - 2ms/step
# Epoch 44/50
# 10/10 - 0s - loss: 0.1057 - accuracy: 0.9645 - val_loss: 0.5137 - val_accuracy: 0.8548 - 17ms/epoch - 2ms/step
# Epoch 45/50
# 10/10 - 0s - loss: 0.1022 - accuracy: 0.9661 - val_loss: 0.5188 - val_accuracy: 0.8548 - 17ms/epoch - 2ms/step
# Epoch 46/50
# 10/10 - 0s - loss: 0.0985 - accuracy: 0.9685 - val_loss: 0.5250 - val_accuracy: 0.8548 - 17ms/epoch - 2ms/step
# Epoch 47/50
# 10/10 - 0s - loss: 0.0951 - accuracy: 0.9709 - val_loss: 0.5306 - val_accuracy: 0.8516 - 17ms/epoch - 2ms/step
# Epoch 48/50
# 10/10 - 0s - loss: 0.0916 - accuracy: 0.9717 - val_loss: 0.5358 - val_accuracy: 0.8516 - 17ms/epoch - 2ms/step
# Epoch 49/50
# 10/10 - 0s - loss: 0.0886 - accuracy: 0.9742 - val_loss: 0.5401 - val_accuracy: 0.8548 - 17ms/epoch - 2ms/step
# Epoch 50/50
# 10/10 - 0s - loss: 0.0851 - accuracy: 0.9733 - val_loss: 0.5469 - val_accuracy: 0.8516 - 30ms/epoch - 3ms/step

# %%
max_val_accuracy = max(history.history['val_accuracy'])
print(f"Maximum Validation Accuracy: {max_val_accuracy * 100:.2f}%")
# Out:
# Maximum Validation Accuracy: 86.45%

# %% [markdown]
# ### Model Comparison and Conclusions
# Validation accuracy is the most important metric to consider when comparing models. We're not very interested in how well the model fits to the training data and instead want a model that can generalize to unseen cases. Rather than consider the final validation accuracy after all epochs of training, we want to compare each model's peak validation accuracy (i.e. the validation accuracy computed before the models start overfitting). The model with the highest peak validation accuracy is model 3, trained on the PCA components and the clustering results. This model achieved a peak validation accuracy of 86.45% (achieved at epoch 14) while peak for model 1 (raw features) was only 84.19% and peak for model 2 (principal components only) was 86.13%. Thus, we would want to use the principal components + cluster results as features rather than the original features to achieve maximum generalizability. However, I've done no tuning on the hyperparameters used in the models above and there could be differences in performance depending on how many principal components we choose to use in the model. Additional tuning and experimenting might result in a different featurization choice.

# %% [markdown]
# ## Discussion Questions

# %% [markdown]
# 1. In your own words, what is the difference between PCA and clustering?

# %% [markdown]
# **PCA is a tool that can be used for dimensionality reduction and is a way of summarizing latent concepts in a dataset with many features. PCA can summarize most of the variation in the data in a much smaller number of components which reduces complexity and provides information about which features contribute to certain larger concepts. For example, PCA might result in the creation of 2 or 3 components that represent latent features in the data like socioeconomic status, geographic location, and health that more succintly capture patterns from hundreds of more specific features. The goals of clustering are different. Rather than dimensionailty reduction or latent feature construction (using other features), clustering simply sorts all observations into distinct groups of similar types of observations. This gives us more information about the observations or research subjects themselves and how they are similar to other subjects (instead of giving us information about the features that contribute most to underlying concepts in the data or reducing dimensionality).**

# %% [markdown]
# 2. Did you notice any advantages to combining PCA and clustering? If so, what do you think they were? If not, why do you think you didn't see any gains from this combination?

# %% [markdown]
# **Yes, I saw advantages to combining PCA and clustering, though only through very slight improvements to peak validation accuracy. The primary advantage seemed to come from replacing the original features with the principal components. However, it does seem that the clustering results provided a small amount of additional information that the model used to improve its prediction accuracy.**

# %% [markdown]
# 3. How can unsupervised techniques help with downstream supervised learning tasks when working with "big data?"

# %% [markdown]
# **Unsupervised learning techniques can help to prepare data for inclusion in supervised models like neural networks. Dimension-reduction techniques like PCA can be thought of as forms of feature engineering that help to eliminate uninformative features and reveal the underlying structure of the data. The problem of uninformative features and ambiguous structure are particularly potent in very large datasets with lots of features; many features might only contribute noise. The better we can prepare our data for inclusion in a deep learning model (or another ML model), the easier it will be for the model to identify patterns and make predictions on unseen data.**
